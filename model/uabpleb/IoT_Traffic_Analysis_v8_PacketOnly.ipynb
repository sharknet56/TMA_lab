# %% [markdown]
# # IoT Traffic Analysis v8 — Packet-only behavioral features (UNSW/Dryad)
#
# This notebook implements **v8 (packet-only)** for IoT device **type** classification using the Dryad/UNSW IoT PCAPs.
#
# What’s new in **v8 packet-only** vs v7:
# - Removes raw port-number features (to reduce shortcut learning).
# - Adds two behavior-oriented packet flags:
#   - `is_retrans_like` (lightweight retransmission-like heuristic)
#   - `is_keepalive_like` (small TCP ACK-ish packets)
#
# What stays the same:
# - Device-level train/test split (generalization to unseen devices)
# - Windowing (fixed #packets per window)
# - 1D CNN classifier
#
# Later variants you mentioned (summary-only, packet+summary, summary-no-direction) can reuse the same dataset split + evaluation blocks.

# %%
# If running in a fresh environment, install deps as needed:
# !pip install scapy tensorflow scikit-learn pandas numpy matplotlib

import os
import math
import random
import numpy as np
import pandas as pd

from scapy.all import PcapReader
from scapy.layers.inet import IP, TCP, UDP, ICMP

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE)

print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %% [markdown]
# ## 1) Dataset location
# Set `PCAP_DIR` to the folder where you extracted `pcaps.zip` from the Dryad dataset.
#
# Expected structure:
# - `PCAP_DIR/*.pcap`

# %%
# === UPDATE THIS PATH ===
PCAP_DIR = "unsw-dataset/pcaps"   # e.g. "/content/pcaps" or "./pcaps"

assert os.path.isdir(PCAP_DIR), f"PCAP_DIR not found: {PCAP_DIR}"
pcap_files = sorted([os.path.join(PCAP_DIR, f) for f in os.listdir(PCAP_DIR) if f.endswith(".pcap")])

print("PCAP count:", len(pcap_files))
print("Example:", pcap_files[:3])
# Out:
# PCAP count: 26
# Example: ['unsw-dataset/pcaps/AmazonEcho_44650d56ccd3.pcap', 'unsw-dataset/pcaps/AugustDoorBell_e076d03f00ae.pcap', 'unsw-dataset/pcaps/AwairAirQuality_70886b100fc6.pcap']

# %% [markdown]
# ## 2) v8 device-type taxonomy + mapping
#
# ### v8 labels (recommended for this dataset)
# We exclude `hub_gateway_bridge` because it is not learnable here (only 2 devices and behavior is not coherent).
#
# - `continuous_streaming`
# - `low_rate_telemetry`
# - `interactive_actuators`
# - `smart_media_clients`
#
# If you want to include hubs later, best practice is either:
# - merge them into an `unknown_infrastructure` class *with more devices*, or
# - drop them from training/eval (recommended for PoC stability).

# %%
# Your provided mapping (v7-style)
device_to_type_v7 = {
    "SamsungCamera_00166cab6b88": "camera_streamer",
    "BelkinCamera_b4750eece5a9": "camera_streamer",
    "NestDropCam_308cfb2fe4b2": "camera_streamer",
    "TPLinkCamera_f4f26D9351f1": "camera_streamer",
    "CanaryCamera_7c70bc5d5edc": "camera_streamer",
    "NetatmoWelcome_70ee50183443": "camera_streamer",
    "WithingsBabyMonitor_0024e41118a8": "camera_streamer",
    "RingDoorBell_884aea31669d": "camera_streamer",
    "AugustDoorBell_e076d03f00ae": "camera_streamer",

    "AwairAirQuality_70886b100fc6": "sensor_meter",
    "NetatmoWeatherStation_70ee5003b8ac": "sensor_meter",
    "WithingsSleepSensor_0024e42028c6": "sensor_meter",
    "WithingsSmartScale_0024e41b6f96": "sensor_meter",
    "BlipCareBPMeter_746a89002e25": "sensor_meter",
    "NestProtect_18b43025bee4": "sensor_meter",
    "BelkinWemoMotionSensor_ec1a59832811": "sensor_meter",

    "PhilipsHue_0017882b9a25": "actuator_light_plug",
    "LiFXBulb_d073d5018308": "actuator_light_plug",
    "TPLinkSmartPlug_50c7bf005639": "actuator_light_plug",
    "BelkinWemoSwitch_ec1a5979f489": "actuator_light_plug",

    "SamsungSmartThings_d052a800675e": "hub_gateway_bridge",
    "HPPrinter_705a0fe49bc0": "hub_gateway_bridge",

    "TribySpeaker_18B79E022044": "media_speaker_display",
    "PixStarPhotoFrame_e076d033bb85": "media_speaker_display",
    "HelloBarbie_28c2ddffa52d": "media_speaker_display",
    "iHome_74c63b29d71d": "media_speaker_display",
    "AmazonEcho_44650d56ccd3": "media_speaker_display",
}

# v8 relabeling
v7_to_v8 = {
    "camera_streamer": "continuous_streaming",
    "sensor_meter": "low_rate_telemetry",
    "actuator_light_plug": "interactive_actuators",
    "media_speaker_display": "smart_media_clients",
    "hub_gateway_bridge": None,  # excluded in v8 by default
}

device_to_type_v8 = {dev: v7_to_v8.get(t, None) for dev, t in device_to_type_v7.items()}

# Control: include or drop devices whose v8 type is None
DROP_NONE_TYPES = True

target_types = sorted([t for t in set(device_to_type_v8.values()) if t is not None])
print("v8 target types:", target_types)

# Quick counts
from collections import Counter
print("Counts:", Counter([t for t in device_to_type_v8.values() if t is not None]))
# Out:
# v8 target types: ['continuous_streaming', 'interactive_actuators', 'low_rate_telemetry', 'smart_media_clients']
# Counts: Counter({'continuous_streaming': 9, 'low_rate_telemetry': 7, 'smart_media_clients': 5, 'interactive_actuators': 4})

# %% [markdown]
# ## 3) Build device table from PCAPs
# We match each PCAP filename (without `.pcap`) to your `device_to_type_v8` mapping.
#
# If your filenames have a different pattern, adjust `device_id_from_path()`.

# %%
def device_id_from_path(pcap_path: str) -> str:
    # Common pattern in this dataset: <DeviceName>_<mac>.pcap
    base = os.path.basename(pcap_path)
    return base.replace(".pcap", "")

rows = []
for p in pcap_files:
    dev = device_id_from_path(p)
    v8_type = device_to_type_v8.get(dev, None)
    if DROP_NONE_TYPES and v8_type is None:
        continue
    if v8_type is None:
        v8_type = "unknown_infrastructure"
    rows.append({"device_id": dev, "device_type": v8_type, "pcap_path": p})

df_dev = pd.DataFrame(rows).sort_values(["device_type", "device_id"]).reset_index(drop=True)
print("Devices included:", len(df_dev))
display(df_dev.head(10))
print(df_dev["device_type"].value_counts())
# Out:
# Devices included: 23
#                        device_id            device_type  \
# 0    AugustDoorBell_e076d03f00ae   continuous_streaming
# 1      BelkinCamera_b4750eece5a9   continuous_streaming
# 2      CanaryCamera_7c70bc5d5edc   continuous_streaming
# 3       NestDropCam_308cfb2fe4b2   continuous_streaming
# 4    NetatmoWelcome_70ee50183443   continuous_streaming
# 5      RingDoorBell_884aea31669d   continuous_streaming
# 6     SamsungCamera_00166cab6b88   continuous_streaming
# 7      TPLinkCamera_f4f26D9351f1   continuous_streaming
# 8  BelkinWemoSwitch_ec1a5979f489  interactive_actuators
# 9          LiFXBulb_d073d5018308  interactive_actuators
#
#                                            pcap_path
# 0  unsw-dataset/pcaps/AugustDoorBell_e076d03f00ae...
# 1  unsw-dataset/pcaps/BelkinCamera_b4750eece5a9.pcap
# 2  unsw-dataset/pcaps/CanaryCamera_7c70bc5d5edc.pcap
# 3   unsw-dataset/pcaps/NestDropCam_308cfb2fe4b2.pcap
# 4  unsw-dataset/pcaps/NetatmoWelcome_70ee50183443...
# 5  unsw-dataset/pcaps/RingDoorBell_884aea31669d.pcap
# 6  unsw-dataset/pcaps/SamsungCamera_00166cab6b88....
# 7  unsw-dataset/pcaps/TPLinkCamera_f4f26D9351f1.pcap
# 8  unsw-dataset/pcaps/BelkinWemoSwitch_ec1a5979f4...
# 9      unsw-dataset/pcaps/LiFXBulb_d073d5018308.pcap
# device_type
# continuous_streaming     8
# low_rate_telemetry       6
# smart_media_clients      5
# interactive_actuators    4
# Name: count, dtype: int64

# %% [markdown]
# ## 4) Train/test split by device (stratified)
# This is the key split for true generalization: the model never sees packets from test devices during training.

# %%
# Label encoding
types = sorted(df_dev["device_type"].unique())
type_to_idx = {t: i for i, t in enumerate(types)}
idx_to_type = {i: t for t, i in type_to_idx.items()}
df_dev["y"] = df_dev["device_type"].map(type_to_idx).astype(int)

# Stratified split by device_type
train_df, test_df = train_test_split(
    df_dev,
    test_size=0.30,
    random_state=RANDOM_STATE,
    stratify=df_dev["device_type"]
)

print("Train devices:", len(train_df), "Test devices:", len(test_df))
print("Train distribution:\n", train_df["device_type"].value_counts())
print("Test distribution:\n", test_df["device_type"].value_counts())
# Out:
# Train devices: 16 Test devices: 7
# Train distribution:
#  device_type
# continuous_streaming     6
# low_rate_telemetry       4
# interactive_actuators    3
# smart_media_clients      3
# Name: count, dtype: int64
# Test distribution:
#  device_type
# continuous_streaming     2
# smart_media_clients      2
# low_rate_telemetry       2
# interactive_actuators    1
# Name: count, dtype: int64

# %% [markdown]
# ## 5) v8 packet-only feature extraction
#
# ### Feature vector (F_DIM=17)
# Per packet:
# 1. `pkt_len_norm` (len(pkt)/1500, clipped)
# 2. `payload_norm` (payload bytes/1500, clipped)
# 3. `iat_norm` (log1p(Δt)/log1p(cap))
# 4. `direction` (1 if src == inferred device IP else 0)
# 5. `ttl_norm` (ttl/255)
# 6-9. `proto_onehot` (TCP, UDP, ICMP, other)
# 10-15. `tcp_flags` (SYN, ACK, FIN, RST, PSH, URG)
# 16. `is_retrans_like` (cheap heuristic based on repeated TCP (sport,dport,seq,payload_len))
# 17. `is_keepalive_like` (small TCP packet, ACK only-ish)
#
# Notes:
# - We infer device IP from the first N packets by most frequent IP.src (same as v7).
# - We deliberately avoid raw ports as numeric features.

# %%
# Windowing
PKTS_PER_WINDOW = 60
STRIDE = 60
MAX_WINDOWS_PER_DEVICE = 1200

# Feature hyperparams
F_DIM = 17
IAT_CAP_SECONDS = 2.0
MTU_NORM = 1500.0

def safe_payload_len(pkt) -> int:
    # Approx payload length: take TCP/UDP payload if present, else 0
    if pkt.haslayer(TCP):
        return int(len(bytes(pkt[TCP].payload)))
    if pkt.haslayer(UDP):
        return int(len(bytes(pkt[UDP].payload)))
    return 0

def tcp_flag_bits(tcp_layer) -> np.ndarray:
    # Order: SYN, ACK, FIN, RST, PSH, URG  (6 dims)
    flags = int(getattr(tcp_layer, "flags", 0))
    def has(flag_char):
        # Scapy uses flag letters in str(tcp.flags), but numeric works too
        return 1.0 if flag_char in str(tcp_layer.flags) else 0.0
    return np.array([has("S"), has("A"), has("F"), has("R"), has("P"), has("U")], dtype=np.float32)

def infer_device_ip(pcap_path: str, scan_packets: int = 200) -> str | None:
    counts = {}
    seen = 0
    with PcapReader(pcap_path) as pcap:
        for pkt in pcap:
            if not pkt.haslayer(IP):
                continue
            src = pkt[IP].src
            counts[src] = counts.get(src, 0) + 1
            seen += 1
            if seen >= scan_packets:
                break
    return max(counts.items(), key=lambda kv: kv[1])[0] if counts else None

def is_keepalive_like(pkt) -> float:
    # Heuristic: TCP packet with very small payload and (mostly) ACK
    if not pkt.haslayer(TCP):
        return 0.0
    pl = safe_payload_len(pkt)
    if pl > 1:
        return 0.0
    fl = str(pkt[TCP].flags)
    # ACK with no SYN/FIN/RST typically => keepalive-ish / pure ACK
    if ("A" in fl) and ("S" not in fl) and ("F" not in fl) and ("R" not in fl):
        # also small packet size
        if len(pkt) <= 80:
            return 1.0
    return 0.0

def iter_feature_windows(pcap_path: str,
                         device_ip: str | None,
                         label: int,
                         max_windows: int = MAX_WINDOWS_PER_DEVICE,
                         pkts_per_window: int = PKTS_PER_WINDOW,
                         stride: int = STRIDE):
    """Yield (window_features, label, device_id) windows from a PCAP."""
    # We maintain a small rolling set for retrans-like detection
    # Key: (src,dst,sport,dport,seq,payload_len). Stored only for TCP packets.
    recent_tcp_keys = []
    recent_tcp_set = set()
    RECENT_MAX = 5000  # bounded memory

    prev_time = None
    feats = []

    windows_yielded = 0
    with PcapReader(pcap_path) as pcap:
        for pkt in pcap:
            if not pkt.haslayer(IP):
                continue

            # IAT
            this_time = float(getattr(pkt, "time", 0.0))
            if prev_time is None or this_time <= 0.0 or prev_time <= 0.0:
                iat = 0.0
            else:
                iat = max(0.0, this_time - prev_time)
            prev_time = this_time
            iat = min(iat, IAT_CAP_SECONDS)

            pkt_len = float(len(pkt))
            payload_len = float(safe_payload_len(pkt))

            ip = pkt[IP]
            ttl = float(getattr(ip, "ttl", 0.0))
            direction = 1.0 if (device_ip is not None and getattr(ip, "src", None) == device_ip) else 0.0

            # Protocol one-hot: TCP, UDP, ICMP, other
            proto = int(getattr(ip, "proto", 0))
            if proto == 6:
                proto_oh = np.array([1.0, 0.0, 0.0, 0.0], dtype=np.float32)
            elif proto == 17:
                proto_oh = np.array([0.0, 1.0, 0.0, 0.0], dtype=np.float32)
            elif proto == 1:
                proto_oh = np.array([0.0, 0.0, 1.0, 0.0], dtype=np.float32)
            else:
                proto_oh = np.array([0.0, 0.0, 0.0, 1.0], dtype=np.float32)

            # TCP flags
            flags = np.zeros(6, dtype=np.float32)
            is_retrans_like = 0.0
            if pkt.haslayer(TCP):
                tcp = pkt[TCP]
                flags = tcp_flag_bits(tcp)
                seq = int(getattr(tcp, "seq", 0))
                sport = int(getattr(tcp, "sport", 0))
                dport = int(getattr(tcp, "dport", 0))
                key = (ip.src, ip.dst, sport, dport, seq, int(payload_len))
                if key in recent_tcp_set:
                    is_retrans_like = 1.0
                # update rolling set
                recent_tcp_keys.append(key)
                recent_tcp_set.add(key)
                if len(recent_tcp_keys) > RECENT_MAX:
                    old = recent_tcp_keys.pop(0)
                    # remove only if not duplicated in list (cheap check)
                    if old not in recent_tcp_keys:
                        recent_tcp_set.discard(old)

            keepalive = is_keepalive_like(pkt)

            # Normalizations
            pkt_len_norm = min(pkt_len / MTU_NORM, 2.0)
            payload_norm = min(payload_len / MTU_NORM, 2.0)
            ttl_norm = ttl / 255.0
            iat_norm = math.log1p(iat) / math.log1p(IAT_CAP_SECONDS)

            feat = np.concatenate([
                np.array([pkt_len_norm, payload_norm, iat_norm, direction, ttl_norm], dtype=np.float32),
                proto_oh,
                flags,
                np.array([is_retrans_like, keepalive], dtype=np.float32)
            ], axis=0).astype(np.float32)

            if feat.shape[0] != F_DIM:
                continue

            feats.append(feat)

            # If we have enough for a window, yield and slide
            if len(feats) >= pkts_per_window:
                window = np.stack(feats[:pkts_per_window], axis=0)
                yield window, label
                windows_yielded += 1
                if windows_yielded >= max_windows:
                    break
                feats = feats[stride:]

# %% [markdown]
# ## 6) tf.data input pipeline
# We stream windows from PCAPs (no full in-memory packet arrays).

# %%
def make_window_generator(df_sub: pd.DataFrame):
    # This closure yields (X, y) across devices, in device-order.
    def gen():
        for _, row in df_sub.iterrows():
            pcap_path = row["pcap_path"]
            y = int(row["y"])
            device_ip = infer_device_ip(pcap_path, scan_packets=200)
            for Xw, yw in iter_feature_windows(pcap_path, device_ip=device_ip, label=y):
                yield Xw, yw
    return gen

output_signature = (
    tf.TensorSpec(shape=(PKTS_PER_WINDOW, F_DIM), dtype=tf.float32),
    tf.TensorSpec(shape=(), dtype=tf.int32),
)

def make_dataset(df_sub: pd.DataFrame, batch_size: int = 64, shuffle: bool = True):
    ds = tf.data.Dataset.from_generator(make_window_generator(df_sub), output_signature=output_signature)
    if shuffle:
        ds = ds.shuffle(2048, seed=RANDOM_STATE, reshuffle_each_iteration=True)
    ds = ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return ds

BATCH_SIZE = 64
train_ds = make_dataset(train_df, batch_size=BATCH_SIZE, shuffle=True)
test_ds = make_dataset(test_df, batch_size=BATCH_SIZE, shuffle=False)

print(train_ds)
# Out:
# 2026-01-14 23:23:39.548371: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 60, 17), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# ## 7) Model (1D CNN)
# Simple, fast baseline. You can later swap this for a small Transformer encoder.

# %%
def make_1d_cnn(n_classes: int) -> tf.keras.Model:
    inp = layers.Input(shape=(PKTS_PER_WINDOW, F_DIM), name="pkt_features")
    x = layers.Conv1D(64, 3, padding="same", activation="relu")(inp)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool1D(2)(x)

    x = layers.Conv1D(128, 3, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool1D(2)(x)

    x = layers.Conv1D(256, 3, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(0.30)(x)
    x = layers.Dense(128, activation="relu")(x)
    x = layers.Dropout(0.25)(x)

    out = layers.Dense(n_classes, activation="softmax")(x)
    model = models.Model(inp, out)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

n_classes = len(types)
model = make_1d_cnn(n_classes)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ pkt_features (InputLayer)       │ (None, 60, 17)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 60, 64)         │         3,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 60, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 30, 128)        │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 30, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 15, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 15, 256)        │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 15, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 161,796 (632.02 KB)
#  Trainable params: 160,900 (628.52 KB)
#  Non-trainable params: 896 (3.50 KB)

# %% [markdown]
# ## 8) Train

# %%
EPOCHS = 25

callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2, min_lr=1e-5)
]

history = model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

plt.figure()
plt.plot(history.history["accuracy"], label="train acc")
plt.plot(history.history["val_accuracy"], label="val acc")
plt.legend()
plt.title("Accuracy")
plt.show()
# Out:
# Epoch 1/25
# 2026-01-14 23:23:56.963848: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 103 of 2048
# 2026-01-14 23:24:16.955910: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 230 of 2048
# 2026-01-14 23:24:37.086016: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 333 of 2048
# 2026-01-14 23:24:57.093380: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 431 of 2048
# 2026-01-14 23:25:17.104154: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 533 of 2048
# 2026-01-14 23:25:37.023621: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 609 of 2048
# 2026-01-14 23:25:57.003401: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 718 of 2048
# 2026-01-14 23:26:16.959506: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 817 of 2048
# 2026-01-14 23:26:27.065122: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 855 of 2048
# 2026-01-14 23:26:37.078931: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 889 of 2048
# 2026-01-14 23:26:57.004727: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1009 of 2048
# 2026-01-14 23:27:16.977068: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1131 of 2048
# 2026-01-14 23:27:36.960396: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1299 of 2048
# 2026-01-14 23:27:47.003579: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1400 of 2048
# 2026-01-14 23:28:07.075250: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1557 of 2048
# 2026-01-14 23:28:17.486809: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1605 of 2048
# 2026-01-14 23:28:37.142779: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1706 of 2048
# 2026-01-14 23:28:47.144587: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1758 of 2048
# 2026-01-14 23:29:06.995101: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1868 of 2048
# 2026-01-14 23:29:27.044940: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 2040 of 2048
# 2026-01-14 23:29:28.102152: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:483] Shuffle buffer filled.
#     285/Unknown 2236s 7s/step - accuracy: 0.9267 - loss: 0.2458
# 2026-01-15 00:00:56.474011: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# /home/uabpleb/Documents/tma_proyecto_final/TMA_lab/model/.venv/lib64/python3.10/site-packages/keras/src/trainers/epoch_iterator.py:164: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2642s 8s/step - accuracy: 0.9434 - loss: 0.2038 - val_accuracy: 0.2070 - val_loss: 2.9744 - learning_rate: 0.0010
# Epoch 2/25
# 2026-01-15 00:07:42.529581: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2026-01-15 00:07:52.590378: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 159 of 2048
# 2026-01-15 00:08:02.605180: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 285 of 2048
# 2026-01-15 00:08:22.577192: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 501 of 2048
# 2026-01-15 00:08:32.608486: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 615 of 2048
# 2026-01-15 00:08:42.612940: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 700 of 2048
# 2026-01-15 00:09:02.687216: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 888 of 2048
# 2026-01-15 00:09:22.567811: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1112 of 2048
# 2026-01-15 00:09:32.584332: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1218 of 2048
# 2026-01-15 00:09:42.595589: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1420 of 2048
# 2026-01-15 00:10:02.601461: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1691 of 2048
# 2026-01-15 00:10:12.606487: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1807 of 2048
# 2026-01-15 00:10:29.688184: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:483] Shuffle buffer filled.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2153s 7s/step - accuracy: 0.9363 - loss: 0.2468 - val_accuracy: 0.2922 - val_loss: 7.3115 - learning_rate: 0.0010
# Epoch 3/25
# 2026-01-15 00:43:35.899910: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2026-01-15 00:43:45.967834: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 133 of 2048
# 2026-01-15 00:43:55.968371: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 246 of 2048
# 2026-01-15 00:44:15.924119: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 446 of 2048
# 2026-01-15 00:44:25.943110: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 567 of 2048
# 2026-01-15 00:44:45.919988: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 783 of 2048
# 2026-01-15 00:44:55.945778: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 879 of 2048
# 2026-01-15 00:45:05.954038: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 998 of 2048
# 2026-01-15 00:45:15.995769: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1129 of 2048
# 2026-01-15 00:45:35.968104: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1487 of 2048
# 2026-01-15 00:45:55.946309: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1821 of 2048
# 2026-01-15 00:46:05.959583: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1987 of 2048
# 2026-01-15 00:46:09.719068: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:483] Shuffle buffer filled.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2109s 7s/step - accuracy: 0.9523 - loss: 0.1748 - val_accuracy: 0.4482 - val_loss: 4.0378 - learning_rate: 0.0010
# Epoch 4/25
# 2026-01-15 01:18:55.329109: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 168 of 2048
# 2026-01-15 01:19:05.361762: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 251 of 2048
# 2026-01-15 01:19:25.359313: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 455 of 2048
# 2026-01-15 01:19:45.291806: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 707 of 2048
# 2026-01-15 01:19:55.313203: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 824 of 2048
# 2026-01-15 01:20:15.343224: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1057 of 2048
# 2026-01-15 01:20:25.384443: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1158 of 2048
# 2026-01-15 01:20:45.386733: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1477 of 2048
# 2026-01-15 01:21:05.324890: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1793 of 2048
# 2026-01-15 01:21:20.578752: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:483] Shuffle buffer filled.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2083s 7s/step - accuracy: 0.9661 - loss: 0.1191 - val_accuracy: 0.6020 - val_loss: 4.9030 - learning_rate: 5.0000e-04
# Epoch 5/25
# 2026-01-15 01:53:28.519276: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2026-01-15 01:53:38.566411: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 159 of 2048
# 2026-01-15 01:53:48.628965: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 265 of 2048
# 2026-01-15 01:54:08.608633: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 500 of 2048
# 2026-01-15 01:54:28.601728: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 730 of 2048
# 2026-01-15 01:54:38.648448: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 832 of 2048
# 2026-01-15 01:54:58.546391: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1030 of 2048
# 2026-01-15 01:55:08.557532: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1136 of 2048
# 2026-01-15 01:55:28.620471: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1482 of 2048
# 2026-01-15 01:55:48.542226: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1803 of 2048
# 2026-01-15 01:55:58.567902: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1989 of 2048
# 2026-01-15 01:56:02.154905: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:483] Shuffle buffer filled.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 2102s 7s/step - accuracy: 0.9739 - loss: 0.0849 - val_accuracy: 0.5371 - val_loss: 4.7089 - learning_rate: 5.0000e-04
# Epoch 6/25
# 2026-01-15 02:28:40.163041: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 174 of 2048
# 2026-01-15 02:29:00.123735: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 429 of 2048
# 2026-01-15 02:29:10.145547: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 562 of 2048
# 2026-01-15 02:29:30.207445: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 768 of 2048
# 2026-01-15 02:29:50.142907: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 979 of 2048
# 2026-01-15 02:30:10.157695: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1188 of 2048
# 2026-01-15 02:30:30.098539: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1608 of 2048
# 2026-01-15 02:30:40.120093: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1781 of 2048
# 2026-01-15 02:30:54.305246: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:483] Shuffle buffer filled.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1996s 7s/step - accuracy: 0.9717 - loss: 0.0881 - val_accuracy: 0.5362 - val_loss: 4.1474 - learning_rate: 2.5000e-04
# Epoch 7/25
# 2026-01-15 03:01:56.374270: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 150 of 2048
# 2026-01-15 03:02:06.389426: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 260 of 2048
# 2026-01-15 03:02:16.416657: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 372 of 2048
# 2026-01-15 03:02:36.401559: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 592 of 2048
# 2026-01-15 03:02:46.404034: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 708 of 2048
# 2026-01-15 03:02:56.439134: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 811 of 2048
# 2026-01-15 03:03:16.351860: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1032 of 2048
# 2026-01-15 03:03:26.406835: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1141 of 2048
# 2026-01-15 03:03:46.388527: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1543 of 2048
# 2026-01-15 03:04:06.390971: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1915 of 2048
# 2026-01-15 03:04:13.921570: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:483] Shuffle buffer filled.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1726s 6s/step - accuracy: 0.9750 - loss: 0.0734 - val_accuracy: 0.4959 - val_loss: 4.5932 - learning_rate: 2.5000e-04
# Epoch 8/25
# 2026-01-15 03:30:42.153032: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 170 of 2048
# 2026-01-15 03:31:02.217077: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 418 of 2048
# 2026-01-15 03:31:22.189455: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 700 of 2048
# 2026-01-15 03:31:42.175620: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1004 of 2048
# 2026-01-15 03:32:02.166828: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1391 of 2048
# 2026-01-15 03:32:12.169658: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1591 of 2048
# 2026-01-15 03:32:32.157009: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1994 of 2048
# 2026-01-15 03:32:34.464921: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:483] Shuffle buffer filled.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1704s 6s/step - accuracy: 0.9757 - loss: 0.0717 - val_accuracy: 0.5000 - val_loss: 4.2131 - learning_rate: 1.2500e-04
# Epoch 9/25
# 2026-01-15 03:58:56.222687: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2026-01-15 03:59:06.314686: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 160 of 2048
# 2026-01-15 03:59:26.298628: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 392 of 2048
# 2026-01-15 03:59:46.283790: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 664 of 2048
# 2026-01-15 03:59:56.318809: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 785 of 2048
# 2026-01-15 04:00:16.253173: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1029 of 2048
# 2026-01-15 04:00:26.267859: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1152 of 2048
# 2026-01-15 04:00:46.280947: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1557 of 2048
# 2026-01-15 04:01:06.240591: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:453] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 1897 of 2048
# 2026-01-15 04:01:15.031989: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:483] Shuffle buffer filled.
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1161s 4s/step - accuracy: 0.9852 - loss: 0.0446 - val_accuracy: 0.5117 - val_loss: 4.0780 - learning_rate: 1.2500e-04

# %% [markdown]
# ## 9) Evaluation
# We report:
# - Window-level metrics (what the model sees)
# - Device-level metrics via aggregation (what you actually care about)

# %%
def collect_window_preds(df_sub: pd.DataFrame, model: tf.keras.Model, max_windows_per_device: int = 500):
    """Return window-level predictions and per-device aggregated predictions."""
    all_true = []
    all_pred = []
    per_device = []  # list of (device_id, y_true, probs_mean, y_pred)

    for _, row in df_sub.iterrows():
        dev = row["device_id"]
        y_true = int(row["y"])
        pcap_path = row["pcap_path"]
        device_ip = infer_device_ip(pcap_path, scan_packets=200)

        probs = []
        wcount = 0
        for Xw, yw in iter_feature_windows(pcap_path, device_ip=device_ip, label=y_true, max_windows=max_windows_per_device):
            p = model.predict(Xw[None, ...], verbose=0)[0]
            probs.append(p)
            y_hat = int(np.argmax(p))
            all_true.append(y_true)
            all_pred.append(y_hat)
            wcount += 1

        if probs:
            probs_mean = np.mean(np.stack(probs, axis=0), axis=0)
            y_dev = int(np.argmax(probs_mean))
        else:
            probs_mean = np.zeros((n_classes,), dtype=np.float32)
            y_dev = -1

        per_device.append((dev, y_true, probs_mean, y_dev, wcount))

    return np.array(all_true), np.array(all_pred), per_device

win_true, win_pred, dev_preds = collect_window_preds(test_df, model, max_windows_per_device=400)

print("Window-level classification report:")
print(classification_report(win_true, win_pred, target_names=types, digits=4))

cm = confusion_matrix(win_true, win_pred, labels=list(range(n_classes)))
plt.figure(figsize=(7, 6))
plt.imshow(cm, interpolation="nearest")
plt.title("Window-level confusion matrix")
plt.colorbar()
plt.xticks(range(n_classes), types, rotation=45, ha="right")
plt.yticks(range(n_classes), types)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.tight_layout()
plt.show()

# Device-level aggregation
dev_true = []
dev_pred = []
print("\nPer-device predictions:")
for dev, y_true, probs_mean, y_dev, wcount in dev_preds:
    if y_dev >= 0:
        dev_true.append(y_true)
        dev_pred.append(y_dev)
    print(f"- {dev:35s} true={idx_to_type[y_true]:22s} pred={idx_to_type.get(y_dev,'(none)'):22s} windows={wcount}")

dev_true = np.array(dev_true)
dev_pred = np.array(dev_pred)

print("\nDevice-level classification report (mean-prob aggregation):")
print(classification_report(dev_true, dev_pred, target_names=types, digits=4))

cm2 = confusion_matrix(dev_true, dev_pred, labels=list(range(n_classes)))
plt.figure(figsize=(7, 6))
plt.imshow(cm2, interpolation="nearest")
plt.title("Device-level confusion matrix")
plt.colorbar()
plt.xticks(range(n_classes), types, rotation=45, ha="right")
plt.yticks(range(n_classes), types)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.tight_layout()
plt.show()
# Out:
# Window-level classification report:
#                        precision    recall  f1-score   support
#
#  continuous_streaming     0.6583    0.9150    0.7657       800
# interactive_actuators     0.7809    0.7575    0.7690       400
#    low_rate_telemetry     0.0000    0.0000    0.0000       408
#   smart_media_clients     0.1093    0.1320    0.1196       462
#
#              accuracy                         0.5295      2070
#             macro avg     0.3871    0.4511    0.4136      2070
#          weighted avg     0.4297    0.5295    0.4712      2070
# Per-device predictions:
# - NestDropCam_308cfb2fe4b2            true=continuous_streaming   pred=continuous_streaming   windows=400
# - PixStarPhotoFrame_e076d033bb85      true=smart_media_clients    pred=continuous_streaming   windows=400
# - PhilipsHue_0017882b9a25             true=interactive_actuators  pred=interactive_actuators  windows=400
# - BlipCareBPMeter_746a89002e25        true=low_rate_telemetry     pred=smart_media_clients    windows=8
# - HelloBarbie_28c2ddffa52d            true=smart_media_clients    pred=smart_media_clients    windows=62
# - WithingsSmartScale_0024e41b6f96     true=low_rate_telemetry     pred=smart_media_clients    windows=400
# - SamsungCamera_00166cab6b88          true=continuous_streaming   pred=continuous_streaming   windows=400
#
# Device-level classification report (mean-prob aggregation):
#                        precision    recall  f1-score   support
#
#  continuous_streaming     0.6667    1.0000    0.8000         2
# interactive_actuators     1.0000    1.0000    1.0000         1
#    low_rate_telemetry     0.0000    0.0000    0.0000         2
#   smart_media_clients     0.3333    0.5000    0.4000         2
#
#              accuracy                         0.5714         7
#             macro avg     0.5000    0.6250    0.5500         7
#          weighted avg     0.4286    0.5714    0.4857         7
# /home/uabpleb/Documents/tma_proyecto_final/TMA_lab/model/.venv/lib64/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/uabpleb/Documents/tma_proyecto_final/TMA_lab/model/.venv/lib64/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/uabpleb/Documents/tma_proyecto_final/TMA_lab/model/.venv/lib64/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# ## 10) Next steps (later prompts)
# - v8 summary-only
# - v8 packet + summary (two-branch model)
# - v8 summary + no direction
#
# This notebook is the packet-only foundation those variants will build on.
